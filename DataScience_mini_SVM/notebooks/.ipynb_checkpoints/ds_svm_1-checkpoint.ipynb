# %% [markdown]
# ### 1. NOTES ON THE OPERATIONS FOR THIS NOTEBOOKS
#
# In this notebooks we are exploring the support vector machine.

# %% [markdown]
# ### 2a. IMPORT PACKAGES AND DEPENDENCIES

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import svm
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### 2b. IMPORT DATASET

# %%
height_df = pd.read_csv(r"C:\Users\User\Desktop\Data_Science_Projects\Datascience_SVM\datasets\Person_Gender_Height_Weight_Index.csv")

# %% [markdown]
# ### 3. GENERAL VIEW OF THE DATASET

# %%
# displays the first five rows of the dataset
height_df.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
# displays the last five rows of the dataset
height_df.tail()
# Out:
#      Gender  Height  Weight  Index
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5

# %%
# displays a stats of columns
height_df.describe()
# Out:
#            Height      Weight       Index
# count  500.000000  500.000000  500.000000
# mean   169.944000  106.000000    3.748000
# std     16.375261   32.382607    1.355053
# min    140.000000   50.000000    0.000000
# 25%    156.000000   80.000000    3.000000
# 50%    170.500000  106.000000    4.000000
# 75%    184.000000  136.000000    5.000000
# max    199.000000  160.000000    5.000000

# %%
height_df.columns
# Out:
# Index(['Gender', 'Height', 'Weight', 'Index'], dtype='object')

# %%
height_df.info
# Out:
# <bound method DataFrame.info of      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]>

# %%
height_df.shape
# Out:
# (500, 4)

# %% [markdown]
# ### 4a. LABEL ENCODE THE MOST IMPORTANT COLUMN TO AVOID BASE i.e Gender Columns

# %%
gender = LabelEncoder()
height_df['Gender'] = gender.fit_transform(height_df['Gender'])
height_df.head()
# Out:
#    Gender  Height  Weight  Index
# 0       1     174      96      4
# 1       1     189      87      2
# 2       0     185     110      4
# 3       0     195     104      3
# 4       1     149      61      3

# %% [markdown]
# ### 4b. CREATE A BIN FOR THE CATERGORISATION OF WEIGHT

# %%
bins = (-1, 0, 1, 2, 3, 4, 5)
health = ['malnourished', 'underweight', 'fit', 'slightly_overweight', 'overweight', 'obese']

# %%
height_df['Index'] = pd.cut(height_df['Index'], bins= bins, labels= health) 
height_df['Index']
# Out:
# 0               overweight
# 1                      fit
# 2               overweight
# 3      slightly_overweight
# 4      slightly_overweight
#               ...
# 495                  obese
# 496             overweight
# 497                  obese
# 498                  obese
# 499                  obese
# Name: Index, Length: 500, dtype: category
# Categories (6, object): [malnourished < underweight < fit < slightly_overweight < overweight < obese]

# %%
height_df.count
# Out:
# <bound method DataFrame.count of      Gender  Height  Weight                Index
# 0         1     174      96           overweight
# 1         1     189      87                  fit
# 2         0     185     110           overweight
# 3         0     195     104  slightly_overweight
# 4         1     149      61  slightly_overweight
# ..      ...     ...     ...                  ...
# 495       0     150     153                obese
# 496       0     184     121           overweight
# 497       0     141     136                obese
# 498       1     150      95                obese
# 499       1     173     131                obese
#
# [500 rows x 4 columns]>

# %%
height_df['Gender'].value_counts()
# Out:
# 0    255
# 1    245
# Name: Gender, dtype: int64

# %% [markdown]
# ### 5. VISUALISE THE RELATIONSHIPS

# %%
sns.countplot(height_df['Index'])

# %%
sns.relplot(x ='Height', y = 'Weight', hue = 'Index', data = height_df)

# %%
sns.relplot(x ='Index', y = 'Weight', hue = 'Gender', data = height_df)

# %%
sns.relplot(x='Height', y= 'Weight', hue= 'Gender', data= height_df)

# %%
sns.relplot(x='Height', y= 'Weight', hue= 'Gender', data= height_df, height= 5, aspect= 3)

# %%
sns.relplot(x ='Index', y = 'Height', hue = 'Gender', 
            data = height_df, height = 5, aspect = 3)

# %%
sns.relplot(x='Index', y= 'Weight', hue= 'Gender', 
            data= height_df, height= 5, aspect= 3)

# %%
# if we visualise using a line plot
sns.relplot(x='Index', y= 'Height', hue= 'Gender', data= height_df, 
            kind= 'line', height= 5, aspect= 3)

# %%
# if we visualise using a line plot
sns.relplot(x='Index', y= 'Weight', hue= 'Gender', data= height_df, 
            kind= 'line', height= 5, aspect= 3)

# %% [markdown]
# ### PREPROCESSING

# %%
x = height_df.drop("Index", axis = 1)
y = height_df['Index']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.4, random_state = 100)

# %%
s = StandardScaler()
x_train = s.fit_transform(x_train)
y_train = s.transform(x_test)

# %%
clf = svm.vcs()
clf.fit(x-train, y_train)
prod = clf.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-110-689d5d308590> in <module>
# ----> 1 clf = svm.vcs()
#       2 clf.fit(x-train, y_train)
#       3 prod = clf.predict(x_test)
#
# AttributeError: module 'sklearn.svm' has no attribute 'vcs'

# %%
print(classification_report(y_test, prod))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-111-0bd1b4127712> in <module>
# ----> 1 print(classification_report(y_test, prod))
#
# NameError: name 'prod' is not defined

# %%
print(confusion_matrix(y_test, prod))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-112-d8bee3914592> in <module>
# ----> 1 print(confusion_matrix(y_test, prod))
#
# NameError: name 'prod' is not defined

# %%
print(accuracy_score(y_test, prod))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-113-edd57bacaeb7> in <module>
# ----> 1 print(accuracy_score(y_test, prod))
#
# NameError: name 'prod' is not defined

# %%
a = [(0, 160, 48)]
a = s.transform(a)
b = clf.predict(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-114-9f65bc4e8961> in <module>
#       1 a = [(0, 160, 48)]
#       2 a = s.transform(a)
# ----> 3 b = clf.predict(a)
#
# NameError: name 'clf' is not defined

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-89e6c98d9288> in <module>
# ----> 1 b
#
# NameError: name 'b' is not defined

# %%
height_df
# Out:
#      Gender  Height  Weight                Index
# 0         1     174      96           overweight
# 1         1     189      87                  fit
# 2         0     185     110           overweight
# 3         0     195     104  slightly_overweight
# 4         1     149      61  slightly_overweight
# ..      ...     ...     ...                  ...
# 495       0     150     153                obese
# 496       0     184     121           overweight
# 497       0     141     136                obese
# 498       1     150      95                obese
# 499       1     173     131                obese
#
# [500 rows x 4 columns]

# %% [markdown]
# **From Edureka Project 2020, Modified by Chisomloius**
